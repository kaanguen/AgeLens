# %% [markdown]
# <a href="https://colab.research.google.com/github/kaanguen/AgeLens/blob/main/notebooks/AgeLensGoogleCollab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install keras
