# %% [markdown]
# <a href="https://colab.research.google.com/github/kaanguen/AgeLens/blob/projectStructure/AgeLensGoogleCollab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # Für Google Collab fürs trainieren
